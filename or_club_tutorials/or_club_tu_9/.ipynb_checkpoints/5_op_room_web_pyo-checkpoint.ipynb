# %%
import datetime as dt
import pyomo.environ as pyo
import pandas as pd
import os.path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/bs/8_rscwxd25z1bcq4d89vsz380000gn/T/ipykernel_19731/1509442338.py in <module>
#       1 import datetime as dt
# ----> 2 import pyomo.environ as pyo
#       3 import pandas as pd
#       4 import os.path
#
# ModuleNotFoundError: No module named 'pyomo'

# %%
# Datum entry
datum="2021 11 24" # provide year, month, day as a script with spaces or select from the calendar
datum = dt.datetime.strptime(datum, '%Y %m %d').date()
today = dt.date.today()


if datum<today:
    print("You selected a day in the past.")

# %%
## inputs we can create a table or sth similar

# department ids
deps=['CH1', 'CH2', 'CH3', 'HT', 'IM1', 'IM2', 'OR1', 'OR2']

# Departments capacities
deps_cap=[660, 435, 600,260,0, 825, 930,0]

dep_df=pd.DataFrame(zip(deps,deps_cap), columns=['dep_name','dep_cap'])
dep_df.index=dep_df["dep_name"]
dep_df=dep_df.drop(['dep_name'], axis=1)


# operation room ids
op_rooms=["HLK1","HLK2","OP1","OP2","OP3","OP4","OP5","OP6"]


# Operation rooms capacities
op_rooms_cap=[435, 390, 555, 555 ,555,435,435,320]

op_df=pd.DataFrame(zip(op_rooms,op_rooms_cap), columns=["op_room_name","op_room_cap"])
op_df.index=op_df["op_room_name"]
op_df=op_df.drop(['op_room_name'], axis=1)

# %%
# output show capacities of opertions rooms
op_df
# Out:
#               op_room_cap
# op_room_name
# HLK1                  435
# HLK2                  390
# OP1                   555
# OP2                   555
# OP3                   555
# OP4                   435
# OP5                   435
# OP6                   320

# %%
# output show capacities of departments
dep_df
# Out:
#           dep_cap
# dep_name
# CH1           660
# CH2           435
# CH3           600
# HT            260
# IM1             0
# IM2           825
# OR1           930
# OR2             0

# %%
# create a csv file to record the entries , if the file does not exist.
if os.path.isfile(f'{datum}.csv'):   
    print("it is there")
    basket=pd.read_csv(f'{datum}.csv', index_col="operation_id")
else:
    # we create an empty dataframe only first time
    basket=pd.DataFrame(columns=['dep_id','ops','weight','value',"op_room_id"])
    basket.index.name = 'operation_id'

#output

# show last 5 entries (output)
print("total weight of basket:", sum(basket['weight']))
basket.tail()
# Out:
# it is there
# total weight of basket: 350
#              dep_id   ops  weight  value op_room_id
# operation_id
# xx_015          CH1  xxxx     160      2       HLK1
# xx_016          CH1  xxxx     190      2       HLK2

# %%
# We populate basket with 5 cells: index, Abteilung-ID, ops, value, weight
# Every entry will be recorded in this table. 


ind='xx_018' # this id can be provided by the departments
basket.loc[ind,'ops']=str("xxxx") # codes of the operations to be done
basket.loc[ind,'dep_id']="CH3" #  Department id  who is asking for the operation
basket.loc[ind,'value']=1 # importance or the urgency of the operation
basket.loc[ind, 'weight']=80 # in minutes


basket.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/bs/8_rscwxd25z1bcq4d89vsz380000gn/T/ipykernel_19731/4214055314.py in <module>
#       4
#       5 ind='xx_018' # this id can be provided by the departments
# ----> 6 basket.loc[ind,'ops']=str("xxxx") # codes of the operations to be done
#       7 basket.loc[ind,'dep_id']="CH3" #  Department id  who is asking for the operation
#       8 basket.loc[ind,'value']=1 # importance or the urgency of the operation
#
# NameError: name 'basket' is not defined

# %%
# multi-knapsack, integer divisible

mdl = pyo.ConcreteModel()

# sets
mdl.invs = pyo.Set(initialize=list(zip(basket.index, basket["dep_id"])))
mdl.bins = pyo.Set(initialize=list(op_df.index))
mdl.deps = pyo.Set(initialize=list(dep_df.index))

# params
mdl.value   = pyo.Param(mdl.invs, initialize= {(i,row["dep_id"]):row["value"] for i,row in basket.iterrows()} )
mdl.weight  = pyo.Param(mdl.invs, initialize= {(i,row["dep_id"]):row["weight"] for i,row in basket.iterrows()})
mdl.bin_cap = pyo.Param(mdl.bins, initialize= {i:row["op_room_cap"] for i,row in op_df.iterrows()} )
mdl.dep_cap = pyo.Param(mdl.deps, initialize= {i:row["dep_cap"] for i,row in dep_df.iterrows()}, mutable=True)



# vars
mdl.X = pyo.Var(mdl.invs, mdl.bins, within=pyo.Binary)     # the amount from invoice i in bin j



### Objective ###

mdl.OBJ = pyo.Objective(expr=sum(mdl.X[i, b]*mdl.value[i] for 
                        i in mdl.invs for
                        b in mdl.bins), sense=pyo.maximize)



### constraints ###

# don't overstuff bin
def bin_limit(self, b):
    return sum(mdl.X[i, b]*mdl.weight[i] for i in mdl.invs) <= mdl.bin_cap[b]
mdl.bin_limit = pyo.Constraint(mdl.bins, rule=bin_limit)

# one_item can be only in a single op room.
def one_item(self, i,d):
    return sum(mdl.X[i,d,b] for b in mdl.bins) <=1
mdl.one_item = pyo.Constraint(mdl.invs, rule=one_item)



# department limits

mdl.dep_limits=pyo.ConstraintList()

for d in mdl.deps:
    d_list=[]
    for i in mdl.X:
        if d==i[1]:
            d_list.append(i)    
    mdl.dep_limits.add(expr=(sum(mdl.X[i]*mdl.weight[i[:2]] for i in d_list)<=mdl.dep_cap[d])) 
        
    



# solve it...
solver = pyo.SolverFactory('glpk')
results = solver.solve(mdl)

# save the output into dataframe



count=0
for i in mdl.X:
    if pyo.value(mdl.X[i])==1:
        count+=pyo.value(mdl.X[i])
        basket.loc[i[0],"op_room_id"]=i[2]
        


# make sure that last item does not cause exclusion of any existing items
# If so, remove last record from the basket        
if basket.shape[0]>count:
    print('Sorry,',basket.tail(1).index,', we cannot offer you a time slot on that day.')
    basket.drop(basket.tail(1).index, inplace=True)
else:
    print(basket.tail())
    basket.to_csv(f'{datum}.csv', index=True)
# Out:
#              dep_id   ops  weight  value op_room_id
# operation_id
# xx_015          CH1  xxxx   160.0    2.0       HLK2
# xx_016          CH1  xxxx   190.0    2.0       HLK2
# xx_017          CH1  xxxx   300.0    2.0       HLK1

# %%
# print output of solution
mdl.display()
# Out:
# Model unknown
#
#   Variables:
#     X : Size=24, Index=X_index
#         Key                       : Lower : Value : Upper : Fixed : Stale : Domain
#         ('xx_015', 'CH1', 'HLK1') :     0 :   0.0 :     1 : False : False : Binary
#         ('xx_015', 'CH1', 'HLK2') :     0 :   1.0 :     1 : False : False : Binary
#          ('xx_015', 'CH1', 'OP1') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_015', 'CH1', 'OP2') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_015', 'CH1', 'OP3') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_015', 'CH1', 'OP4') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_015', 'CH1', 'OP5') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_015', 'CH1', 'OP6') :     0 :   0.0 :     1 : False : False : Binary
#         ('xx_016', 'CH1', 'HLK1') :     0 :   0.0 :     1 : False : False : Binary
#         ('xx_016', 'CH1', 'HLK2') :     0 :   1.0 :     1 : False : False : Binary
#          ('xx_016', 'CH1', 'OP1') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_016', 'CH1', 'OP2') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_016', 'CH1', 'OP3') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_016', 'CH1', 'OP4') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_016', 'CH1', 'OP5') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_016', 'CH1', 'OP6') :     0 :   0.0 :     1 : False : False : Binary
#         ('xx_017', 'CH1', 'HLK1') :     0 :   1.0 :     1 : False : False : Binary
#         ('xx_017', 'CH1', 'HLK2') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_017', 'CH1', 'OP1') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_017', 'CH1', 'OP2') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_017', 'CH1', 'OP3') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_017', 'CH1', 'OP4') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_017', 'CH1', 'OP5') :     0 :   0.0 :     1 : False : False : Binary
#          ('xx_017', 'CH1', 'OP6') :     0 :   0.0 :     1 : False : False : Binary
#
#   Objectives:
#     OBJ : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True :   6.0
#
#   Constraints:
#     bin_limit : Size=8
#         Key  : Lower : Body  : Upper
#         HLK1 :  None : 300.0 : 435.0
#         HLK2 :  None : 350.0 : 390.0
#          OP1 :  None :   0.0 : 555.0
#          OP2 :  None :   0.0 : 555.0
#          OP3 :  None :   0.0 : 555.0
#          OP4 :  None :   0.0 : 435.0
#          OP5 :  None :   0.0 : 435.0
#          OP6 :  None :   0.0 : 320.0
#     one_item : Size=3
#         Key               : Lower : Body : Upper
#         ('xx_015', 'CH1') :  None :  1.0 :   1.0
#         ('xx_016', 'CH1') :  None :  1.0 :   1.0
#         ('xx_017', 'CH1') :  None :  1.0 :   1.0
#     dep_limits : Size=8
#         Key : Lower : Body  : Upper
#           1 :  None : 650.0 :   660
#           2 :  None :   0.0 :   435
#           3 :  None :   0.0 :   600
#           4 :  None :   0.0 :   260
#           5 :  None :   0.0 :     0
#           6 :  None :   0.0 :   825
#           7 :  None :   0.0 :   930
#           8 :  None :   0.0 :     0

# %%
basket.tail()
# Out:
#              dep_id   ops  weight  value op_room_id
# operation_id
# xx_015          CH1  xxxx   160.0    2.0       HLK2
# xx_016          CH1  xxxx   190.0    2.0       HLK2
# xx_017          CH1  xxxx   300.0    2.0       HLK1
